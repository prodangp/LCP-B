# %%
import numpy as np
import matplotlib.pyplot as plt
# XGBoost 
from xgboost import XGBRegressor
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error
# Out:
# /home/prody/anaconda3/envs/unipd/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
np.random.seed(123)

CASE = 11

S = 2
N = 1000
N_train = 500
N_test  = N - N_train
x = S*(2*np.random.rand(N,2)-1)
y = np.zeros(N) # float
for n in range(N):
    y[n] = -100.*x[n,0] 
    if CASE==11: y[n] += 100.*np.cos(3.14*x[n,1])
    if CASE==12: y[n] += -100.*x[n,1] 

x_train,y_train = x[:N_train],y[:N_train]
x_test,y_test = x[N_train:],y[N_train:]

# %%
def scat(x,y,s=4,cmap="plasma"):
    plt.scatter(x[:,0],x[:,1],s=s,c=y,cmap=cmap)

for n in range(5):
    print(x[n],y[n])

plt.figure(figsize=(12,8))
scat(x_train,y_train,s=7)
plt.colorbar()
scat(x_test,y_test,cmap="winter",s=12)
plt.colorbar()
plt.show()
# Out:
# [ 0.78587674 -0.85544266] -168.39167391263723
# [-1.09259419  0.20525908] 189.19863413401646
# [ 0.87787588 -0.30757416] -30.91027271561145
# [1.92305679 0.73931895] -260.51821147160183
# [-0.07627239 -0.43152993] 29.03938677467515

# %%
print(y[:4])
# Out:
# [-168.39167391  189.19863413  -30.91027272 -260.51821147]

# %%
def fit(xgbr=XGBRegressor(),show=False):
    # GradientBoostingClassifier():
    #   n_estimators = 100 (default)
    #   loss function = deviance(default) used in Logistic Regression
    # XGBClassifier()
    #   n_estimators = 100 (default)
    #   max_depth = 3 (default)
    xgbr.fit(x_train,y_train)
    y_hat = xgbr.predict(x_test)
    print("mean squared error: {:.2f}".format(mean_squared_error(y_hat, y_test)))
    if show: 
        dx = 0.02
        x_seq=np.arange(-S,S+dx,dx)
        nx = len(x_seq)
        x_plot=np.zeros((nx*nx,2))
        q=0
        for i in range(nx):
            for j in range(nx):
                x_plot[q,:] = [x_seq[i],x_seq[j]]
                q+=1
        y_plot= xgbr.predict(x_plot)

        plt.figure(figsize=(9.5,8))
        plt.title(str(xgbr))
        scat(x_plot,y_plot,cmap="winter",s=0.2)
        plt.colorbar()
        scat(x_train,y_train,s=7)
        plt.show()
    if show:      
        dump_list = xgbr.get_booster().get_dump()
        num_trees = len(dump_list)
        print("num_trees=",num_trees)
        
        fig, AX = plt.subplots(3,1,figsize=(30, 30))
        for i in range(min(3,num_trees)):
            ax=AX[i]
            plot_tree(xgbr, num_trees=i, ax=ax)
        fig.savefig("DATA/tree-fit.png", dpi=300, pad_inches=0.02)   
        plt.show()
        #plt.savefig("net"+str(t)+".png",dpi=300)
        plt.show()

# %%
fit(XGBRegressor(seed=1,reg_lambda=50., n_estimators=100,max_depth=3),show=True)
# Out:
# mean squared error: 143.33
# num_trees= 100
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/unipd/lib/python3.9/site-packages/xgboost/plotting.py:171, in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     170 try:
# --> 171     from graphviz import Source
#     172 except ImportError as e:
#
# ModuleNotFoundError: No module named 'graphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 fit(XGBRegressor(seed=1,reg_lambda=50., n_estimators=100,max_depth=3),show=True)
#
# Input In [5], in fit(xgbr, show)
#      35 for i in range(min(3,num_trees)):
#      36     ax=AX[i]
# ---> 37     plot_tree(xgbr, num_trees=i, ax=ax)
#      38 fig.savefig("DATA/tree-fit.png", dpi=300, pad_inches=0.02)
#      39 plt.show()
#
# File ~/anaconda3/envs/unipd/lib/python3.9/site-packages/xgboost/plotting.py:247, in plot_tree(booster, fmap, num_trees, rankdir, ax, **kwargs)
#     244 if ax is None:
#     245     _, ax = plt.subplots(1, 1)
# --> 247 g = to_graphviz(booster, fmap=fmap, num_trees=num_trees, rankdir=rankdir,
#     248                 **kwargs)
#     250 s = BytesIO()
#     251 s.write(g.pipe(format='png'))
#
# File ~/anaconda3/envs/unipd/lib/python3.9/site-packages/xgboost/plotting.py:173, in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     171     from graphviz import Source
#     172 except ImportError as e:
# --> 173     raise ImportError('You must install graphviz to plot tree') from e
#     174 if isinstance(booster, XGBModel):
#     175     booster = booster.get_booster()
#
# ImportError: You must install graphviz to plot tree

# %%
lam=[100.,30,20.,10.,5.,1.,0.5,0.1]
for l in lam:
    print("lambda=",l)
    fit(XGBRegressor(seed=1,reg_lambda=l, n_estimators=100,max_depth=4))
# Out:
# lambda= 100.0
# mean squared error: 218.64
# lambda= 30
# mean squared error: 142.29
# lambda= 20.0
# mean squared error: 128.49
# lambda= 10.0
# mean squared error: 137.28
# lambda= 5.0
# mean squared error: 131.75
# lambda= 1.0
# mean squared error: 146.00
# lambda= 0.5
# mean squared error: 160.90
# lambda= 0.1
# mean squared error: 171.44

# %%
gam=[0.,1.,2.,4.,10.,20.,40.,100.,200.]
for g in gam:
    print("gamma=",g)
    fit(XGBRegressor(seed=1,reg_lambda=5., gamma=g, n_estimators=100,max_depth=4))
# Out:
# gamma= 0.0
# mean squared error: 131.75
# gamma= 1.0
# mean squared error: 129.84
# gamma= 2.0
# mean squared error: 133.77
# gamma= 4.0
# mean squared error: 131.16
# gamma= 10.0
# mean squared error: 126.20
# gamma= 20.0
# mean squared error: 133.90
# gamma= 40.0
# mean squared error: 132.41
# gamma= 100.0
# mean squared error: 160.72
# gamma= 200.0
# mean squared error: 176.82
